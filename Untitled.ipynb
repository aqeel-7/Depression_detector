# %%
import tweepy
import pandas as pd

consumer_key='u9L8y92xb1S0OrqydndNzM3Al'
consumer_secret='UD0Rt625HHjnMwWKc5PH0YPLO2JE8aOzuGq39vLfVBU9zYWlm4'

access_token='1308707110281195521-kYVJKftHmUlBEGNPIDzgH6iBuVBaxH'
access_token_secret='VuvHmZ52CSTleeiFAnUXnF00rK9LmToi0zZRQiZRkuDGQ'

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

api = tweepy.API(auth)
user = api.get_user('@Average_Jonas')
print('Screen Name: ',user.screen_name)
print('Follower Count: ',user.followers_count)
for friend in user.friends():
       print(friend.screen_name)
        
public_tweets = api.home_timeline()
for tweet in public_tweets:
    print(tweet.text)
# Out:
# Screen Name:  Average_Jonas
# Follower Count:  11826
# dearcindyphan
# NVD_Overtime
# Ethieen
# d00mbr0s
# Creativ_B
# G2Patitek
# aleksandarosa
# LEC
# thecodemiko
# T1
# GenG
# RiotBallerina
# play_BTW
# HamillHimself
# mikeshinoda
# Aon1r
# BiancaXisadora
# TheM0rri
# _PLAYERR1
# minon501
# Get ready for the Doctor in 4K HDR on @BBCiPlayer if you're watching in the UK! 🇬🇧 ➡️ https://t.co/viQw5U32jF https://t.co/Auq05MUcj7
# RT @DWOMinecraft: Psst.. It's almost Christmas day! That means we're approaching your last chance to wrap a present for your friends and/or…
# We know that for many of us, Christmas won't be the same this year; lots of us are missing family, friends &amp; loved… https://t.co/gitwGUY4Z9
# Can't wait until New Year's Day for more Daleks? 💥
#
# Watch their best moments on the Doctor Who YouTube channel:… https://t.co/DY0ziC0ZkQ
# Just remember... #WednesdayWisdom https://t.co/jFsenxHUFJ
# ...

# %%
from tweepy import redirect_user
auth = tweepy.OAuthHandler("consumer_key", "consumer_secret")

# Redirect user to Twitter to authorize
redirect_user(auth.get_authorization_url())

# Get access token
auth.get_access_token("verifier_value")

# Construct the API instance
api = tweepy.API(auth)

# %%
status = api.get_status('pictureofmooon', tweet_mode="extended")
try:
    print(status.retweeted_status.full_text)
except AttributeError:  # Not a Retweet
    print(status.full_text)

# %%
def on_status(self, status):
    if hasattr(status, "retweeted_status"):  # Check if Retweet
        try:
            print(status.retweeted_status.extended_tweet["full_text"])
        except AttributeError:
            print(status.retweeted_status.text)
    else:
        try:
            print(status.extended_tweet["full_text"])
        except AttributeError:
            print(status.text)

# %%
username = 'pictureofmooon'
count = 200
try:     
     # Creation of query method using parameters
         tweets = tweepy.Cursor(api.user_timeline,id=username).items(count)

     # Pulling information from tweets iterable object
         tweets_list = [[tweet.created_at, tweet.id, tweet.text] for tweet in tweets]

     # Creation of dataframe from tweets list
     # Add or remove columns as you remove tweet information
         tweets_df = pd.DataFrame(tweets_list)
except BaseException as e:
      print('failed on_status,',str(e))
      time.sleep(3)

# %%
tweets_df.head()

# %%
import re
import io
import csv
import tweepy
from tweepy import OAuthHandler

#TextBlob perform simple natural language processing tasks.
#from textblob import TextBlob


consumer_key = 'sz6x0nvL0ls9wacR64MZu23z4'
consumer_secret = 'ofeGnzduikcHX6iaQMqBCIJ666m6nXAQACIAXMJaFhmC6rjRmT'
access_token = '854004678127910913-PUPfQYxIjpBWjXOgE25kys8kmDJdY0G'
access_token_secret = 'BC2TxbhKXkdkZ91DXofF7GX8p2JNfbpHqhshW1bwQkgxN'
# create OAuthHandler object
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
# set access token and secret
auth.set_access_token(access_token, access_token_secret)
# create tweepy API object to fetch tweets
api = tweepy.API(auth)




def get_tweets(query, count = 300):

    # empty list to store parsed tweets
    tweets = []
    target = io.open("mytweets.csv", 'w', encoding='utf-8')
    # call twitter api to fetch tweets
    q=str(query)
    a=str(q+" sarcasm")
    b=str(q+" sarcastic")
    c=str(q+" irony")
    fetched_tweets = api.search(a, count = count)+ api.search(b, count = count)+ api.search(c, count = count)
    # parsing tweets one by one
    print(len(fetched_tweets))

    for tweet in fetched_tweets:

        # empty dictionary to store required params of a tweet
        parsed_tweet = {}
        # saving text of tweet
        parsed_tweet['text'] = tweet.text
        print(tweet._json)
        if "http" not in tweet.text:
            line = re.sub("[^A-Za-z]", " ", tweet.text)
            target.write(line+"\n")
#             print(tweet)
    return fetched_tweets

    # creating object of TwitterClient Class
    # calling function to get tweets
tweets = get_tweets(query ="depression", count = 20)

# %%
list_json=[tweets[0]._json]
# Out:
# {'created_at': 'Tue Dec 22 07:55:53 +0000 2020',
#  'id': 1341291356342243330,
#  'id_str': '1341291356342243330',
#  'text': "This made me realise that I've never used I will die of annoyance or I will die of boredom or such phrases very rar… https://t.co/U80V4ESRVr",
#  'truncated': True,
#  'entities': {'hashtags': [],
#   'symbols': [],
#   'user_mentions': [],
#   'urls': [{'url': 'https://t.co/U80V4ESRVr',
#     'expanded_url': 'https://twitter.com/i/web/status/1341291356342243330',
#     'display_url': 'twitter.com/i/web/status/1…',
#     'indices': [117, 140]}]},
#  'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#  'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'in_reply_to_screen_name': None,
#  'user': {'id': 918690319817883649,
#   'id_str': '918690319817883649',
# ...

# %%
list_json=[]

[list_json.append(tweet._json) for tweet in tweets]
# Out:
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
list(list_json[1].keys())
# Out:
# ['created_at',
#  'id',
#  'id_str',
#  'text',
#  'truncated',
#  'entities',
#  'metadata',
#  'source',
#  'in_reply_to_status_id',
#  'in_reply_to_status_id_str',
#  'in_reply_to_user_id',
#  'in_reply_to_user_id_str',
#  'in_reply_to_screen_name',
#  'user',
#  'geo',
#  'coordinates',
#  'place',
#  'contributors',
#  'is_quote_status',
#  'retweet_count',
#  'favorite_count',
#  'favorited',
#  'retweeted',
#  'lang']

# %%
list_json_2=[del my_dict['key'] for json in list_json]

# %%
#del list_json[0]['quoted_status_id']#['quoted_status']
list_json[0].keys()
# Out:
# dict_keys(['created_at', 'id', 'id_str', 'text', 'truncated', 'entities', 'metadata', 'source', 'in_reply_to_status_id', 'in_reply_to_status_id_str', 'in_reply_to_user_id', 'in_reply_to_user_id_str', 'in_reply_to_screen_name', 'user', 'geo', 'coordinates', 'place', 'contributors', 'retweeted_status', 'is_quote_status', 'quoted_status_id_str', 'retweet_count', 'favorite_count', 'favorited', 'retweeted', 'lang'])

# %%
def key_remover(my_dict,key):
    try:
        del my_dict[key]
        print('deleted')
    except KeyError:
        pass
    
    return my_dict

# %%
key_remover(list_json[3],'quoted_status').keys()
# Out:
# dict_keys(['created_at', 'id', 'id_str', 'text', 'truncated', 'entities', 'metadata', 'source', 'in_reply_to_status_id', 'in_reply_to_status_id_str', 'in_reply_to_user_id', 'in_reply_to_user_id_str', 'in_reply_to_screen_name', 'user', 'geo', 'coordinates', 'place', 'contributors', 'is_quote_status', 'retweet_count', 'favorite_count', 'favorited', 'retweeted', 'possibly_sensitive', 'lang'])

# %%
type(list_json)

type(list_json[0])
# Out:
# dict

# %%
import csv
toCSV = list_json
with open('json_converted.csv', 'w', encoding='utf8', newline='') as output_file:
    fc = csv.DictWriter(output_file, 
                        fieldnames=list(toCSV[0].keys()),

                       )
    fc.writeheader()
    fc.writerows(toCSV)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-bf00c01c09aa> in <module>
#       7                        )
#       8     fc.writeheader()
# ----> 9     fc.writerows(toCSV)
#
# D:\Program Files (x86)\anaconda3\envs\twitter\lib\csv.py in writerows(self, rowdicts)
#     156
#     157     def writerows(self, rowdicts):
# --> 158         return self.writer.writerows(map(self._dict_to_list, rowdicts))
#     159
#     160 # Guard Sniffer's type checking against builds that exclude complex()
#
# D:\Program Files (x86)\anaconda3\envs\twitter\lib\csv.py in _dict_to_list(self, rowdict)
#     149             if wrong_fields:
#     150                 raise ValueError("dict contains fields not in fieldnames: "
# --> 151                                  + ", ".join([repr(x) for x in wrong_fields]))
# ...

# %%
tweets

# %%
# 2nd git changes
# 3rd git change

# %% [markdown]
# # Code for streaming tweets with particular keywords

# %%
import tweepy
import pandas as pd

consumer_key='u9L8y92xb1S0OrqydndNzM3Al'
consumer_secret='UD0Rt625HHjnMwWKc5PH0YPLO2JE8aOzuGq39vLfVBU9zYWlm4'

access_token='1308707110281195521-kYVJKftHmUlBEGNPIDzgH6iBuVBaxH'
access_token_secret='VuvHmZ52CSTleeiFAnUXnF00rK9LmToi0zZRQiZRkuDGQ'

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

api = tweepy.API(auth)

#override tweepy.StreamListener to add logic to on_status
class MyStreamListener(tweepy.StreamListener):

    def on_status(self, status):
        print(status.text)

# %%
myStreamListener = MyStreamListener()
myStream = tweepy.Stream(auth = api.auth, listener=myStreamListener)

# %%
myStream.filter(track=['depression'])

# %% [markdown]
# # Try 3

# %%
import tweepy
import csv #Import csv
import os

# Consumer keys and access tokens, used for OAuth
consumer_key='u9L8y92xb1S0OrqydndNzM3Al'
consumer_secret='UD0Rt625HHjnMwWKc5PH0YPLO2JE8aOzuGq39vLfVBU9zYWlm4'

access_token='1308707110281195521-kYVJKftHmUlBEGNPIDzgH6iBuVBaxH'
access_token_secret='VuvHmZ52CSTleeiFAnUXnF00rK9LmToi0zZRQiZRkuDGQ'


# OAuth process, using the keys and tokens
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)


api = tweepy.API(auth)
# Open/Create a file to append data

with open('docker1.csv', 'a') as csvFile:
#Use csv Writer
    csvWriter = csv.writer(csvFile,delimiter='\t')
    csvWriter.writerow(['created_at', "text.encode('utf-8')", 'favorite_count', 'retweet_count', 'tweet_id', 'user.screen_name'])

    ids = set()
    for tweet in tweepy.Cursor(api.search,tweet_mode="extended", 
                        q="depression -filter:retweets", 
                        Since="2020-03-1", 
                        until="2021-01-8", 
                        lang="en").items(10000):
        print('=>   : ',tweet.full_text)

        #Write a row to the csv file/ I use encode utf-8
        csvWriter.writerow([tweet.created_at, tweet.full_text.encode('utf-8'), tweet.favorite_count, tweet.retweet_count, tweet.id, tweet.user.screen_name])
        #print "...%s tweets downloaded so far" % (len(tweet.id))
        ids.add(tweet.id) # add new id
        print ("number of unique ids seen so far: {}",format(len(ids)))
    csvFile.close()
# Out:
# =>   :  intelligence of the grossest.  no one knew where they are there. be careful.  depression can come and go in these areas.  best to walk way when we can.
# children, kids happiness can not be controlled
# number of unique ids seen so far: {} 1
# =>   :  Depression is real 🥴
# number of unique ids seen so far: {} 2
# =>   :  @nikotheturnip Yikes :c
# *offers comfort foods and drinks*
# I uhh have mild depression, memory / concentration issues, plus my interests &amp; skills are 'too' varied so I only have surface lvl knowledge of anything really + not many connections so yeah fun times trying to find a job 🙃🙃🙃 asfhjkl
# number of unique ids seen so far: {} 3
# =>   :  @OsitaNwanevu I would also say for a control study, one would have to examine the effects of similar declines in religiosity across other western nations on life expectancy, depression, suicide rates and so on, if that is indeed Douthat’s premise.
# number of unique ids seen so far: {} 4
# ...

# %%
type('asd')
# Out:
# str

# %%
print(u'\xf0\x9f\xa5\xb4')
# Out:
# ð¥´

# %%
print("\xe2\x80\xa6")
# Out:
# â¦
